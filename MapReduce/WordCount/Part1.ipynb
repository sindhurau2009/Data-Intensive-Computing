# %%
library("twitteR")

# %%
setup_twitter_oauth("dIOk7Zoe1ggv1nt9DUz7mf5l2","AfgmA3uH7HrLYJWdBagvkMaHJutCtVq7l5U3PLc1DfMR8pNNZH","774008633948594176-UKdDUoFOmKZfDG5kzGXRvC7KWDBbQLx","p0ylTSARIap5FxDzuFraPQxVQmswEEv40cOQcxg7bp2wd")
# Out:
# [1] "Using direct authentication"

# %%
tweets1 <- searchTwitter("Afghanistan",n=1000)

# %%
tweets1
# Out:
# [[1]]
# [1] "Iza77789584: RT @JoshHallGOP: President Trump visited a military hospital yesterday &amp; awarded a purple heart to Alvaro Barrientos, a soldier injured in"
#
# [[2]]
# [1] "JozefTvardzik: Old, Ill and Ordered Deported From Denmark to Afghanistan https://t.co/cskshTsYzl"
#
# [[3]]
# [1] "gp_theelixir: RT @PathanAsmakhan: This Banner in #Afghanistan Shows how #India is influencing the world. Thank you Honourable PM @narendramodi ji. @ashra"
#
# [[4]]
# [1] "Djibee29: RT @jeannettebougra: #Talibans continuent de tuer #Afghanistan 140 morts à Mazar-i-Sharif. Ne pas oublier ! https://t.co/sLW2f7ZPpa #terror"
#
# [[5]]
# [1] "RayStar07: RT @akhiMarcus: My heart aches for Afghanistan. When will such a beautiful country with such beautiful people get a taste of freedom?"
#
# [[6]]
# [1] "realmojesse5372: RT @TerranceCreamer: R.I.P US Army 1st Lt. Jonathan P. Walsh, 28 of Cobb, Georgia, KIA (April 22, 2012) in Mirhasan, Afghanistan! https://t"
#
# [[7]]
# ...

# %%
df <- twListToDF(tweets1)

# %%
names(df)
# Out:
#  [1] "text"          "favorited"     "favoriteCount" "replyToSN"
#  [5] "created"       "truncated"     "replyToSID"    "id"
#  [9] "replyToUID"    "statusSource"  "screenName"    "retweetCount"
# [13] "isRetweet"     "retweeted"     "longitude"     "latitude"

# %%
df
# Out:
#      text
# 1    RT @JoshHallGOP: President Trump visited a military hospital yesterday &amp; awarded a purple heart to Alvaro Barrientos, a soldier injured in
# 2    Old, Ill and Ordered Deported From Denmark to Afghanistan https://t.co/cskshTsYzl
# 3    RT @PathanAsmakhan: This Banner in #Afghanistan Shows how #India is influencing the world. Thank you Honourable PM @narendramodi ji. @ashra
# 4    RT @jeannettebougra: #Talibans continuent de tuer #Afghanistan 140 morts à Mazar-i-Sharif. Ne pas oublier ! https://t.co/sLW2f7ZPpa #terror
# 5    RT @akhiMarcus: My heart aches for Afghanistan. When will such a beautiful country with such beautiful people get a taste of freedom?
# 6    RT @TerranceCreamer: R.I.P US Army 1st Lt. Jonathan P. Walsh, 28 of Cobb, Georgia, KIA (April 22, 2012) in Mirhasan, Afghanistan! https://t
# 7    RT @DefenseOne: Don't be fooled by the Syria strike or the MOAB in Afghanistan, @DanDePetris says. Trump's still no interventionist. https:
# ...

# %%
df$isRetweet
# Out:
#    [1]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE FALSE
#   [13] FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#   [25] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE FALSE
#   [37]  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE  TRUE
#   [49]  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [61]  TRUE FALSE  TRUE FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#   [73]  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#   [85]  TRUE FALSE  TRUE FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [97]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [109] FALSE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE FALSE  TRUE FALSE  TRUE
#  [121]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [133]  TRUE FALSE  TRUE  TRUE FALSE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
# ...

# %%
df2 <- df$text
head(df2,n=10)
# Out:
#  [1] "RT @JoshHallGOP: President Trump visited a military hospital yesterday &amp; awarded a purple heart to Alvaro Barrientos, a soldier injured in"
#  [2] "Old, Ill and Ordered Deported From Denmark to Afghanistan https://t.co/cskshTsYzl"
#  [3] "RT @PathanAsmakhan: This Banner in #Afghanistan Shows how #India is influencing the world. Thank you Honourable PM @narendramodi ji. @ashra"
#  [4] "RT @jeannettebougra: #Talibans continuent de tuer #Afghanistan 140 morts à Mazar-i-Sharif. Ne pas oublier ! https://t.co/sLW2f7ZPpa #terror"
#  [5] "RT @akhiMarcus: My heart aches for Afghanistan. When will such a beautiful country with such beautiful people get a taste of freedom?"
#  [6] "RT @TerranceCreamer: R.I.P US Army 1st Lt. Jonathan P. Walsh, 28 of Cobb, Georgia, KIA (April 22, 2012) in Mirhasan, Afghanistan! https://t"
#  [7] "RT @DefenseOne: Don't be fooled by the Syria strike or the MOAB in Afghanistan, @DanDePetris says. Trump's still no interventionist. https:"
# ...

# %%
cl_tweets <- gsub("&amp","",df2)

# %%
head(cl_tweets)
# Out:
# [1] "RT @JoshHallGOP: President Trump visited a military hospital yesterday ; awarded a purple heart to Alvaro Barrientos, a soldier injured in"
# [2] "Old, Ill and Ordered Deported From Denmark to Afghanistan https://t.co/cskshTsYzl"
# [3] "RT @PathanAsmakhan: This Banner in #Afghanistan Shows how #India is influencing the world. Thank you Honourable PM @narendramodi ji. @ashra"
# [4] "RT @jeannettebougra: #Talibans continuent de tuer #Afghanistan 140 morts à Mazar-i-Sharif. Ne pas oublier ! https://t.co/sLW2f7ZPpa #terror"
# [5] "RT @akhiMarcus: My heart aches for Afghanistan. When will such a beautiful country with such beautiful people get a taste of freedom?"
# [6] "RT @TerranceCreamer: R.I.P US Army 1st Lt. Jonathan P. Walsh, 28 of Cobb, Georgia, KIA (April 22, 2012) in Mirhasan, Afghanistan! https://t"

# %%
  cl_tweets = gsub("(RT|via)((?:\\b\\W*@\\w+)+)", "", cl_tweets)
  cl_tweets = gsub("@\\w+", "", cl_tweets)
  cl_tweets = gsub("[[:punct:]]", "", cl_tweets)
  cl_tweets = gsub("[[:digit:]]", "", cl_tweets)
  cl_tweets = gsub("http\\w+", "", cl_tweets)
  cl_tweets = gsub("[ \t]{2,}", "", cl_tweets)
  cl_tweets = gsub("^\\s+|\\s+$", "", cl_tweets)

# %%
head(cl_tweets,n=10)
# Out:
#  [1] "President Trump visited a military hospital yesterdayawarded a purple heart to Alvaro Barrientos a soldier injured in"
#  [2] "Old Ill and Ordered Deported From Denmark to Afghanistan"
#  [3] "This Banner in Afghanistan Shows how India is influencing the world Thank you Honourable PMji "
#  [4] "Talibans continuent de tuer Afghanistanmorts à MazariSharif Ne pas oublierterror"
#  [5] "My heart aches for Afghanistan When will such a beautiful country with such beautiful people get a taste of freedom"
#  [6] "RIP US Army st Lt Jonathan P Walshof Cobb Georgia KIA Aprilin Mirhasan Afghanistan "
#  [7] "Dont be fooled by the Syria strike or the MOAB in Afghanistansays Trumps still no interventionist "
#  [8] "Today we remember Pat Tillman Pat left his career in the NFL to join the Army afterhe died on this dayyears ago"
#  [9] "Old Ill and Ordered Deported From Denmark to Afghanistan State discrimination at work"
# [10] "They were the ones who started the"

# %%
install.packages("tm",repos="https://cran.rstudio.com")
# Out:
# Installing package into 'C:/Users/AvinashReddy/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# Warning message:
# "package 'tm' is in use and will not be installed"

# %%
library("tm")

# %%
stopwords_regex = paste(stopwords('en'), collapse = '\\b|\\b')
stopwords_regex = paste0('\\b', stopwords_regex, '\\b')
cl_tweets = stringr::str_replace_all(cl_tweets, stopwords_regex, '')

# %%
head(cl_tweets)
# Out:
# [1] "President Trump visited  military hospital yesterdayawarded  purple heart  Alvaro Barrientos  soldier injured "
# [2] "Old Ill  Ordered Deported From Denmark  Afghanistan"
# [3] "This Banner  Afghanistan Shows  India  influencing  world Thank  Honourable PMji "
# [4] "Talibans continuent de tuer Afghanistanmorts à MazariSharif Ne pas oublierterror"
# [5] "My heart aches  Afghanistan When will   beautiful country   beautiful people get  taste  freedom"
# [6] "RIP US Army st Lt Jonathan P Walshof Cobb Georgia KIA Aprilin Mirhasan Afghanistan "

# %%
write.table(cl_tweets,"Tweets1.txt")

# %%
data = read.csv("Tweets1.csv")

# %%
data
# Out:
#      A.5.AS                      X1
# 1    AWANInews\t1\nAbout           1
# 2    Afghanistan\t24\nAfteryears   1
# 3    Air\t1\nAirport               1
# 4    All\t1\nAmerica               4
# 5    AmericaIsBack\t2\nAmericas    1
# 6    Amerikanen\t1\nAnyone         1
# 7    Anytime\t2\nArchive           1
# 8    Awfully\t1\nBREAKING         42
# 9    BREAKINGPentagon\t1\nBecause  1
# 10   Bombs\t3\nBreaking            3
# 11   BreakingThe\t1\nBrozoDato     1
# 12   Bruh\t1\nByjustof             2
# 13   CNN\t2\nCall                  1
# 14   Can\t1\nComparing             1
# 15   Con\t1\nDear                  9
# 16   Decisiveness\t3\nDefinition   1
# 17   Devastating\t10\nDo           3
# 18   Donald\t1\nDont               1
# 19   Dropping\t2\nEEUU             2
# 20   El\t1\nEn                     3
# 21   Estas\t1\nEvening             1
# 22   Everything\t1\nFBI           10
# 23   FIRST\t1\nFYI                 1
# 24   First\t6\nFootage             1
# ...

# %%
install.packages("extrafont",repos="https://cran.rstudio.com")
# Out:
# Installing package into 'C:/Users/AvinashReddy/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "InternetOpenUrl failed: 'A connection with the server could not be established'"Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# "download of package 'extrafont' failed"

# %%
library("extrafont")
# Out:
# Registering fonts with R

# %%
install.packages("tagcloud",repos="https://cran.rstudio.com")
# Out:
# Installing package into 'C:/Users/AvinashReddy/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "InternetOpenUrl failed: 'A connection with the server could not be established'"Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# "download of package 'tagcloud' failed"

# %%
library("tagcloud")
# Out:
# Warning message:
# "package 'tagcloud' was built under R version 3.3.3"Loading required package: Rcpp

# %%
install.packages("wordcloud",repos="https://cran.rstudio.com")
library("wordcloud")
# Out:
# Installing package into 'C:/Users/AvinashReddy/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "InternetOpenUrl failed: 'A connection with the server could not be established'"Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# "download of package 'wordcloud' failed"Warning message:
# "package 'wordcloud' was built under R version 3.3.3"Loading required package: RColorBrewer

# %%
colnames(data) <- c("Words","Weight")

# %%
data
# Out:
#      Words                       Weight
# 1    AWANInews\t1\nAbout           1
# 2    Afghanistan\t24\nAfteryears   1
# 3    Air\t1\nAirport               1
# 4    All\t1\nAmerica               4
# 5    AmericaIsBack\t2\nAmericas    1
# 6    Amerikanen\t1\nAnyone         1
# 7    Anytime\t2\nArchive           1
# 8    Awfully\t1\nBREAKING         42
# 9    BREAKINGPentagon\t1\nBecause  1
# 10   Bombs\t3\nBreaking            3
# 11   BreakingThe\t1\nBrozoDato     1
# 12   Bruh\t1\nByjustof             2
# 13   CNN\t2\nCall                  1
# 14   Can\t1\nComparing             1
# 15   Con\t1\nDear                  9
# 16   Decisiveness\t3\nDefinition   1
# 17   Devastating\t10\nDo           3
# 18   Donald\t1\nDont               1
# 19   Dropping\t2\nEEUU             2
# 20   El\t1\nEn                     3
# 21   Estas\t1\nEvening             1
# 22   Everything\t1\nFBI           10
# 23   FIRST\t1\nFYI                 1
# 24   First\t6\nFootage             1
# ...

# %%
wordcloud(data$Words, freq=data$Weight, colors=brewer.pal(8,"Dark2"), max.words=200)
# Out:
# plot without title
